# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %matplotlib inline
sns.set_style('whitegrid')

# %% [markdown]
# ### Finding out basic data about the given dataset

# %%
df = pd.read_csv('problem_2/problem_2_train.csv', parse_dates=['memcreateddate','mobilepurchasedate','claimintdate','pickupStartdate'])
df.head()
# Out:
#       srno mobmake  hubid  hubpincode  pickuppartnerid  deliverypartnerid  \
# 0  2851218      AN      7      500004              233                233
# 1  2838330      AJ     10      226010              233                233
# 2  2835781      AJ      2      110018              233                233
# 3  2838589      AM      2      110018              233                233
# 4  2855214      AN     21      110015              233                233
#
#    insuranceCompanyId custpincodecategory claimtype  custpincode  \
# 0                 131                   A      ADLD       500001
# 1                 131                   A      ADLD       226022
# 2                 228                   A      ADLD       110018
# 3                 228                   B      ADLD       124001
# 4                 131                   A      ADLD       201301
#
#   memcreateddate mobilepurchasedate claimintdate  servicecntrid  \
# 0     2017-04-27         2016-12-02   2018-02-08           4403
# 1     2017-03-06         2017-03-05   2018-02-04           4444
# 2     2018-02-01         2018-01-27   2018-02-03           4388
# 3     2018-01-17         2018-01-31   2018-02-04           4092
# 4     2018-01-23         2018-01-20   2018-02-09           4580
#
#   pickupStartdate  tat_in_days
# 0      2018-02-13            5
# 1      2018-02-08           12
# 2      2018-02-12            9
# 3      2018-02-14            9
# 4      2018-02-14            8

# %%
df['delta'] = (df.pickupStartdate - df.claimintdate).dt.days

# %%
df.head()
# Out:
#       srno mobmake  hubid  hubpincode  pickuppartnerid  deliverypartnerid  \
# 0  2851218      AN      7      500004              233                233
# 1  2838330      AJ     10      226010              233                233
# 2  2835781      AJ      2      110018              233                233
# 3  2838589      AM      2      110018              233                233
# 4  2855214      AN     21      110015              233                233
#
#    insuranceCompanyId custpincodecategory claimtype  custpincode  \
# 0                 131                   A      ADLD       500001
# 1                 131                   A      ADLD       226022
# 2                 228                   A      ADLD       110018
# 3                 228                   B      ADLD       124001
# 4                 131                   A      ADLD       201301
#
#   memcreateddate mobilepurchasedate claimintdate  servicecntrid  \
# 0     2017-04-27         2016-12-02   2018-02-08           4403
# 1     2017-03-06         2017-03-05   2018-02-04           4444
# 2     2018-02-01         2018-01-27   2018-02-03           4388
# 3     2018-01-17         2018-01-31   2018-02-04           4092
# 4     2018-01-23         2018-01-20   2018-02-09           4580
#
#   pickupStartdate  tat_in_days  delta
# 0      2018-02-13            5      5
# 1      2018-02-08           12      4
# 2      2018-02-12            9      9
# 3      2018-02-14            9     10
# 4      2018-02-14            8      5

# %%
cate_cols = ['mobmake', 'hubid', 'hubpincode', 'pickuppartnerid','deliverypartnerid', 'insuranceCompanyId', 'custpincodecategory', 'claimtype', 'custpincode', 'servicecntrid']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df[cate_cols] = df[cate_cols].apply(lambda col: le.fit_transform(col))

# %%
df.head()
# Out:
#       srno  mobmake  hubid  hubpincode  pickuppartnerid  deliverypartnerid  \
# 0  2851218       12      7          13                2                  2
# 1  2838330        8     10           6                2                  2
# 2  2835781        8      2           2                2                  2
# 3  2838589       11      2           2                2                  2
# 4  2855214       12     14           1                2                  2
#
#    insuranceCompanyId  custpincodecategory  claimtype  custpincode  \
# 0                   0                    1          0         1085
# 1                   0                    1          0          423
# 2                   1                    1          0           16
# 3                   1                    2          0          129
# 4                   0                    1          0          369
#
#   memcreateddate mobilepurchasedate claimintdate  servicecntrid  \
# 0     2017-04-27         2016-12-02   2018-02-08             49
# 1     2017-03-06         2017-03-05   2018-02-04             74
# 2     2018-02-01         2018-01-27   2018-02-03             39
# 3     2018-01-17         2018-01-31   2018-02-04             23
# 4     2018-01-23         2018-01-20   2018-02-09            128
#
#   pickupStartdate  tat_in_days  delta
# 0      2018-02-13            5      5
# 1      2018-02-08           12      4
# 2      2018-02-12            9      9
# 3      2018-02-14            9     10
# 4      2018-02-14            8      5

# %%
df.describe().T
# Out:
#                       count          mean           std        min  \
# srno                 6250.0  2.946134e+06  77334.798276  2818359.0
# mobmake              6250.0  1.220848e+01      5.926597        0.0
# hubid                6250.0  8.990880e+00      6.006537        0.0
# hubpincode           6250.0  8.519840e+00      6.149522        0.0
# pickuppartnerid      6250.0  1.982560e+00      0.370780        0.0
# deliverypartnerid    6250.0  2.049600e+00      0.351624        0.0
# insuranceCompanyId   6250.0  2.478400e-01      0.431793        0.0
# custpincodecategory  6250.0  1.432000e+00      0.787728        0.0
# claimtype            6250.0  6.400000e-04      0.025292        0.0
# custpincode          6250.0  7.549381e+02    571.561061        0.0
# servicecntrid        6250.0  8.513024e+01     42.012785        0.0
# tat_in_days          6250.0  1.273040e+01      5.075533        2.0
# delta                6250.0  6.116960e+00      5.100455        0.0
#
#                             25%        50%         75%        max
# srno                 2877225.50  2944426.5  3012237.25  3101035.0
# mobmake                    8.00       12.0       16.75       37.0
# hubid                      3.00        8.0       14.00       20.0
# hubpincode                 2.00        9.0       13.00       20.0
# pickuppartnerid            2.00        2.0        2.00        3.0
# deliverypartnerid          2.00        2.0        2.00        3.0
# insuranceCompanyId         0.00        0.0        0.00        1.0
# custpincodecategory        1.00        1.0        2.00        4.0
# claimtype                  0.00        0.0        0.00        1.0
# custpincode              184.25      716.5     1287.00     1922.0
# servicecntrid             46.00       89.0      128.00      136.0
# tat_in_days                9.00       12.0       15.00       57.0
# delta                      3.00        5.0        7.00       58.0

# %%
X = df.loc[:,['mobmake', 'hubid', 'pickuppartnerid', 'servicecntrid']].to_numpy()
y = df['tat_in_days']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
linreg = LinearRegression()
linreg.fit(X_train, y_train)
y_pred = linreg.predict(X_test)
print(np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 5.021125447559873

# %%
corr = df.corr(method='pearson')
corr
# Out:
#                          srno   mobmake     hubid  hubpincode  \
# srno                 1.000000 -0.019769  0.278725   -0.016398
# mobmake             -0.019769  1.000000 -0.169564   -0.064015
# hubid                0.278725 -0.169564  1.000000    0.036654
# hubpincode          -0.016398 -0.064015  0.036654    1.000000
# pickuppartnerid      0.110273 -0.003661  0.001366   -0.062908
# deliverypartnerid    0.054755 -0.003427 -0.020546   -0.021547
# insuranceCompanyId   0.039475 -0.068907 -0.137029   -0.084808
# custpincodecategory -0.048235 -0.005001  0.078080    0.080223
# claimtype           -0.002469  0.030069 -0.005228    0.009178
# custpincode         -0.009595 -0.026166  0.031992    0.918392
# servicecntrid        0.045381  0.057154  0.414590    0.140172
# tat_in_days         -0.193610  0.162024 -0.111797    0.003148
# delta               -0.112862  0.020612 -0.008626   -0.028949
#
#                      pickuppartnerid  deliverypartnerid  insuranceCompanyId  \
# srno                        0.110273           0.054755            0.039475
# mobmake                    -0.003661          -0.003427           -0.068907
# hubid                       0.001366          -0.020546           -0.137029
# hubpincode                 -0.062908          -0.021547           -0.084808
# pickuppartnerid             1.000000           0.238619            0.090972
# deliverypartnerid           0.238619           1.000000           -0.013523
# insuranceCompanyId          0.090972          -0.013523            1.000000
# custpincodecategory        -0.129255          -0.036352           -0.080530
# claimtype                  -0.015874          -0.039558            0.044086
# custpincode                -0.096325          -0.043808           -0.089714
# servicecntrid              -0.009439           0.010189           -0.195954
# tat_in_days                -0.150543          -0.114093           -0.033617
# delta                       0.001163           0.012737           -0.053346
#
#                      custpincodecategory  claimtype  custpincode  \
# srno                           -0.048235  -0.002469    -0.009595
# mobmake                        -0.005001   0.030069    -0.026166
# hubid                           0.078080  -0.005228     0.031992
# hubpincode                      0.080223   0.009178     0.918392
# pickuppartnerid                -0.129255  -0.015874    -0.096325
# deliverypartnerid              -0.036352  -0.039558    -0.043808
# insuranceCompanyId             -0.080530   0.044086    -0.089714
# custpincodecategory             1.000000  -0.005847     0.127887
# claimtype                      -0.005847   1.000000     0.006866
# custpincode                     0.127887   0.006866     1.000000
# servicecntrid                   0.099103   0.006699     0.156474
# tat_in_days                     0.162138   0.078633     0.039493
# delta                           0.019923  -0.001821    -0.034470
#
#                      servicecntrid  tat_in_days     delta
# srno                      0.045381    -0.193610 -0.112862
# mobmake                   0.057154     0.162024  0.020612
# hubid                     0.414590    -0.111797 -0.008626
# hubpincode                0.140172     0.003148 -0.028949
# pickuppartnerid          -0.009439    -0.150543  0.001163
# deliverypartnerid         0.010189    -0.114093  0.012737
# insuranceCompanyId       -0.195954    -0.033617 -0.053346
# custpincodecategory       0.099103     0.162138  0.019923
# claimtype                 0.006699     0.078633 -0.001821
# custpincode               0.156474     0.039493 -0.034470
# servicecntrid             1.000000    -0.138736  0.000166
# tat_in_days              -0.138736     1.000000  0.064870
# delta                     0.000166     0.064870  1.000000

# %%
sns.heatmap(corr)
